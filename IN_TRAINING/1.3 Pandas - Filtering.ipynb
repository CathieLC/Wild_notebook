# %%
import pandas as pd
import numpy as np

link = 'https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/imdb_1000.csv'

df = pd.read_csv(link)

# %%
df.shape
# Out:
# (979, 6)

# %%
df2 = df.head()
df2
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
df2[['first_actor', 'second_actor']] = df2['actors_list'].str.split('\', u', n=1, expand=True)
df2.drop(columns=['actors_list'], inplace=True)
df2
# Out:
# C:\Users\cathe\anaconda3\lib\site-packages\pandas\core\frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# C:\Users\cathe\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# ...

# %%
df2
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#          first_actor                          second_actor
# 0     [u'Tim Robbins      'Morgan Freeman', u'Bob Gunton']
# 1   [u'Marlon Brando           'Al Pacino', u'James Caan']
# 2       [u'Al Pacino   'Robert De Niro', u'Robert Duvall']
# 3  [u'Christian Bale     'Heath Ledger', u'Aaron Eckhart']
# 4   [u'John Travolta  'Uma Thurman', u'Samuel L. Jackson']

# %%
df2[['second', 'third']] = df2['second_actor3'].str.split(',', n=1, expand=True)
df2.drop(columns=['second_actor3'], inplace=True)
df2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'second_actor3'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df2.drop(columns=['second_actor2'], inplace=True)
df2
# Out:
# C:\Users\cathe\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#          first_actor            second                   third
# 0     [u'Tim Robbins  'Morgan Freeman'          u'Bob Gunton']
# 1   [u'Marlon Brando       'Al Pacino'          u'James Caan']
# ...

# %%
df2.rename(columns={'first_actor':'first'}, inplace=True)
df2
# Out:
# C:\Users\cathe\anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                first            second                   third
# 0     [u'Tim Robbins  'Morgan Freeman'          u'Bob Gunton']
# 1   [u'Marlon Brando       'Al Pacino'          u'James Caan']
# ...

# %%
# a partir de là on prend un autre df

df3 = df2
df3
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#             first            second                   third
# 0     Tim Robbins  'Morgan Freeman'          u'Bob Gunton']
# 1   Marlon Brando       'Al Pacino'          u'James Caan']
# 2       Al Pacino  'Robert De Niro'       u'Robert Duvall']
# 3  Christian Bale    'Heath Ledger'       u'Aaron Eckhart']
# 4   John Travolta     'Uma Thurman'   u'Samuel L. Jackson']

# %%
df3['third'].replace("u'", "").replace("']", "")
df3
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#             first            second                   third
# 0     Tim Robbins  'Morgan Freeman'          u'Bob Gunton']
# 1   Marlon Brando       'Al Pacino'          u'James Caan']
# 2       Al Pacino  'Robert De Niro'       u'Robert Duvall']
# 3  Christian Bale    'Heath Ledger'       u'Aaron Eckhart']
# 4   John Travolta     'Uma Thurman'   u'Samuel L. Jackson']

# %%
df3
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#             first            second                   third
# 0     Tim Robbins  'Morgan Freeman'          u'Bob Gunton']
# 1   Marlon Brando       'Al Pacino'          u'James Caan']
# 2       Al Pacino  'Robert De Niro'       u'Robert Duvall']
# 3  Christian Bale    'Heath Ledger'       u'Aaron Eckhart']
# 4   John Travolta     'Uma Thurman'   u'Samuel L. Jackson']

# %%
df3[df3['third'].str[2:]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8996/4038768353.py in <module>
# ----> 1 df3[df3['third'].str[2:]]
#
# NameError: name 'df3' is not defined
