# %%
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %% [markdown]
# Chargement de l'API

# %%
link = 'https://data.nantesmetropole.fr/api/records/1.0/search/?dataset=244400404_stations-velos-libre-service-nantes-metropole-disponibilites&q=&facet=banking&facet=bonus&facet=status&facet=contract_name'

r = requests.get(link)
r.json()
# Out:
# {'nhits': 127,
#  'parameters': {'dataset': ['244400404_stations-velos-libre-service-nantes-metropole-disponibilites'],
#   'rows': 10,
#   'start': 0,
#   'facet': ['banking', 'bonus', 'status', 'contract_name'],
#   'format': 'json',
#   'timezone': 'UTC'},
#  'records': [{'datasetid': '244400404_stations-velos-libre-service-nantes-metropole-disponibilites',
#    'recordid': 'fff11334fc42e45ca8ccd6fd74147188ceb21735',
#    'fields': {'available_bike_stands': 13,
#     'bike_stands': 13,
#     'number': 28,
#     'address': "2, rue de Gigant - Place de l'Edit de Nantes",
#     'name': '028-ÉDIT DE NANTES',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'nantes',
#     'position': [47.2144634274, -1.56756801666],
#     'available_bikes': 0,
#     'status': 'OPEN',
#     'last_update': '2021-10-19T07:22:48+00:00'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-1.56756801666, 47.2144634274]}},
#   {'datasetid': '244400404_stations-velos-libre-service-nantes-metropole-disponibilites',
#    'recordid': '47bc41dcd402bb80e1293a73bae4f669adacbb1b',
#    'fields': {'available_bike_stands': 1,
#     'bike_stands': 5,
#     'number': 1016,
#     'name': 'STATION PARAM CGB',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'nantes',
#     'position': [48.799015, 1.948458],
#     'available_bikes': 0,
#     'status': 'OPEN',
#     'last_update': '2021-11-05T09:20:48+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [1.948458, 48.799015]}},
#   {'datasetid': '244400404_stations-velos-libre-service-nantes-metropole-disponibilites',
#    'recordid': '0936ef4cd68763e1bc12ea1ae6f9f7cedf4992e4',
#    'fields': {'available_bike_stands': 31,
#     'bike_stands': 40,
#     'number': 38,
#     'address': 'Place Alexis-Ricordeau - Chaussée de la Madeleine',
#     'name': '038-RICORDEAU',
#     'bonus': 'False',
#     'banking': 'True',
#     'contract_name': 'nantes',
#     'status': 'OPEN',
#     'available_bikes': 8,
#     'position': [47.2121084631418, -1.55304912932047],
#     'last_update': '2021-12-20T16:37:13+00:00'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-1.55304912932047, 47.2121084631418]}},
#   {'datasetid': '244400404_stations-velos-libre-service-nantes-metropole-disponibilites',
#    'recordid': '992ae6b63fc1d7149c5ac78397eb7da6fbe62e5a',
#    'fields': {'available_bike_stands': 14,
#     'bike_stands': 15,
#     'number': 79,
#     'address': '15, quai de Malakoff',
#     'name': '079-MALAKOFF',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'nantes',
#     'status': 'OPEN',
#     'available_bikes': 1,
#     'position': [47.213395, -1.536954],
#     'last_update': '2021-12-20T16:38:58+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [-1.536954, 47.213395]}},
#   {'datasetid': '244400404_stations-velos-libre-service-nantes-metropole-disponibilites',
#    'recordid': 'b8f0f9b57d5d3aa2ed51493553850d12f811e6b6',
#    'fields': {'available_bike_stands': 9,
#     'bike_stands': 14,
#     'number': 32,
#     'address': 'Place Foch',
#     'name': '032-FOCH',
#     'bonus': 'False',
#     'banking': 'True',
#     'contract_name': 'nantes',
#     'status': 'OPEN',
#     'available_bikes': 2,
#     'position': [47.2192484, -1.550185],
#     'last_update': '2021-12-20T16:38:20+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [-1.550185, 47.2192484]}},
#   {'datasetid': '244400404_stations-velos-libre-service-nantes-metropole-disponibilites',
#    'recordid': '8c6686ae7aff4583a73d1834a60c4ac1c2f45e91',
#    'fields': {'available_bike_stands': 13,
#     'bike_stands': 14,
#     'number': 17,
#     'address': '4, place Sainte Elisabeth',
#     'name': '017-SAINTE ÉLISABETH',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'nantes',
#     'status': 'OPEN',
#     'available_bikes': 1,
#     'position': [47.2192139526135, -1.56157014764171],
#     'last_update': '2021-12-20T16:38:47+00:00'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-1.56157014764171, 47.2192139526135]}},
#   {'datasetid': '244400404_stations-velos-libre-service-nantes-metropole-disponibilites',
#    'recordid': 'b12ccb4c03bfa6fa81782d7f1efa28eae5fd75fc',
#    'fields': {'available_bike_stands': 9,
#     'bike_stands': 20,
#     'number': 51,
#     'address': '5, boulevard de Berlin',
#     'name': '051-TABARLY',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'nantes',
#     'status': 'OPEN',
#     'available_bikes': 11,
#     'position': [47.2141946314965, -1.52973588598036],
#     'last_update': '2021-12-20T16:36:34+00:00'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-1.52973588598036, 47.2141946314965]}},
#   {'datasetid': '244400404_stations-velos-libre-service-nantes-metropole-disponibilites',
#    'recordid': '2816032a28cf95dda25314d62bead9c5a88c883b',
#    'fields': {'available_bike_stands': 11,
#     'bike_stands': 27,
#     'number': 37,
#     'address': "1, allée de l'Île Gloriette",
#     'name': '037-FÉLIX ÉBOUÉ',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'nantes',
#     'status': 'OPEN',
#     'available_bikes': 16,
#     'position': [47.211465063355, -1.5568245371939],
#     'last_update': '2021-12-20T16:36:26+00:00'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-1.5568245371939, 47.211465063355]}},
#   {'datasetid': '244400404_stations-velos-libre-service-nantes-metropole-disponibilites',
#    'recordid': 'ca84b4656a878ebbb9126cc05a2300a8c80c8e13',
#    'fields': {'available_bike_stands': 11,
#     'bike_stands': 14,
#     'number': 71,
#     'address': '18, rue Talensac - 26, rue de Bel Air',
#     'name': '071-TALENSAC NORD',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'nantes',
#     'status': 'OPEN',
#     'available_bikes': 3,
#     'position': [47.2218536381884, -1.5589407466907401],
#     'last_update': '2021-12-20T16:36:55+00:00'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-1.5589407466907401, 47.2218536381884]}},
#   {'datasetid': '244400404_stations-velos-libre-service-nantes-metropole-disponibilites',
#    'recordid': 'e8300734ef7d64dd81850d987cd1edbe29c8d625',
#    'fields': {'available_bike_stands': 8,
#     'bike_stands': 16,
#     'number': 86,
#     'address': 'Rue de Berry - Rue des Hauts Pavés',
#     'name': '086-HAUTS PAVÉS',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'nantes',
#     'status': 'OPEN',
#     'available_bikes': 8,
#     'position': [47.2254706269804, -1.56750184250227],
#     'last_update': '2021-12-20T16:35:45+00:00'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-1.56750184250227, 47.2254706269804]}}],
#  'facet_groups': [{'name': 'banking',
#    'facets': [{'name': 'False',
#      'count': 94,
#      'state': 'displayed',
#      'path': 'False'},
#     {'name': 'True', 'count': 33, 'state': 'displayed', 'path': 'True'}]},
#   {'name': 'bonus',
#    'facets': [{'name': 'False',
#      'count': 127,
#      'state': 'displayed',
#      'path': 'False'}]},
#   {'name': 'status',
#    'facets': [{'name': 'OPEN',
#      'count': 126,
#      'state': 'displayed',
#      'path': 'OPEN'},
#     {'name': 'CLOSED', 'count': 1, 'state': 'displayed', 'path': 'CLOSED'}]},
#   {'name': 'contract_name',
#    'facets': [{'name': 'nantes',
#      'count': 127,
#      'state': 'refined',
#      'path': 'nantes'}]}]}

# %% [markdown]
# Affiche un DataFrame avec l'adresse de chaque station, et le taux de remplissage associé (c'est-à-dire le nombre de vélos disponibles available_bikes / le nombre d'emplacement total bike_stands.

# %%
# tx remplissage = available_bikes / bike_stands

# normalize data json with pandas
data = pd.json_normalize(r.json())

# %%
df = pd.json_normalize(r.json(), record_path= "records")[['fields.address', 'fields.available_bike_stands', 'fields.bike_stands']]
                  
df['taux_remplissage'] = (df['fields.available_bike_stands']/df['fields.bike_stands'])*100
df = df.drop(['fields.available_bike_stands','fields.bike_stands'], axis=1).rename(columns={'fields.address':'Adresse_velo'})
df
# Out:
#                                         Adresse_velo  taux_remplissage
# 0       2, rue de Gigant - Place de l'Edit de Nantes        100.000000
# 1                                                NaN         20.000000
# 2  Place Alexis-Ricordeau - Chaussée de la Madeleine         77.500000
# 3                               15, quai de Malakoff         93.333333
# 4                                         Place Foch         64.285714
# 5                          4, place Sainte Elisabeth         92.857143
# 6                             5, boulevard de Berlin         45.000000
# 7                        1, allée de l'Île Gloriette         40.740741
# 8              18, rue Talensac - 26, rue de Bel Air         78.571429
# 9                 Rue de Berry - Rue des Hauts Pavés         50.000000
