# %%
import pandas as pd

link = 'https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/imdb_1000.csv'
df = pd.read_csv(link)

# %%
# Map used for substituting each value in a Series with another value, here replace series by str

df['actors_list'] = df['actors_list'].map(str)

# %%
#create a loop for cleaning base with replace [ and u and ' and ]...

for i in range(len(df['actors_list'])):
    df['actors_list'][i] = df['actors_list'][i].replace("[u\'", "").replace("u\'", "").replace("\'", '').replace("]","").replace("u\"", "").replace("\"", "")
    
df
# Out:
# C:\Users\cathe\AppData\Local\Temp/ipykernel_68/2628048337.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['actors_list'][i] = df['actors_list'][i].replace("[u\'", "").replace("u\'", "").replace("\'", '').replace("]","").replace("u\"", "").replace("\"", "")
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# ...

# %%
# split before explode

df['actors_list'] = df['actors_list'].str.split(",")
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
# explode for one row with one value of actors_list column

df = df.explode('actors_list')
df
# Out:
#      star_rating                     title content_rating   genre  duration  \
# 0            9.3  The Shawshank Redemption              R   Crime       142
# 0            9.3  The Shawshank Redemption              R   Crime       142
# 0            9.3  The Shawshank Redemption              R   Crime       142
# 1            9.2             The Godfather              R   Crime       175
# 1            9.2             The Godfather              R   Crime       175
# ..           ...                       ...            ...     ...       ...
# 977          7.4               Poltergeist             PG  Horror       114
# 977          7.4               Poltergeist             PG  Horror       114
# 978          7.4               Wall Street              R   Crime       126
# 978          7.4               Wall Street              R   Crime       126
# 978          7.4               Wall Street              R   Crime       126
#
#           actors_list
# 0         Tim Robbins
# ...

# %%
#reset index for df

df = df.reset_index(drop=True)
df
# Out:
#       star_rating                     title content_rating   genre  duration  \
# 0             9.3  The Shawshank Redemption              R   Crime       142
# 1             9.3  The Shawshank Redemption              R   Crime       142
# 2             9.3  The Shawshank Redemption              R   Crime       142
# 3             9.2             The Godfather              R   Crime       175
# 4             9.2             The Godfather              R   Crime       175
# ...           ...                       ...            ...     ...       ...
# 2932          7.4               Poltergeist             PG  Horror       114
# 2933          7.4               Poltergeist             PG  Horror       114
# 2934          7.4               Wall Street              R   Crime       126
# 2935          7.4               Wall Street              R   Crime       126
# 2936          7.4               Wall Street              R   Crime       126
#
#            actors_list
# ...

# %%
#check 
df
# Out:
#       star_rating                     title content_rating   genre  duration  \
# 0             9.3  The Shawshank Redemption              R   Crime       142
# 1             9.3  The Shawshank Redemption              R   Crime       142
# 2             9.3  The Shawshank Redemption              R   Crime       142
# 3             9.2             The Godfather              R   Crime       175
# 4             9.2             The Godfather              R   Crime       175
# ...           ...                       ...            ...     ...       ...
# 2932          7.4               Poltergeist             PG  Horror       114
# 2933          7.4               Poltergeist             PG  Horror       114
# 2934          7.4               Wall Street              R   Crime       126
# 2935          7.4               Wall Street              R   Crime       126
# 2936          7.4               Wall Street              R   Crime       126
#
#            actors_list
# ...

# %%
# Which actor is mentionned most often ?
df['actors_list'].value_counts().idxmax()
# Out:
# 'Robert De Niro'

# %%
f"The actor is mentioned the most often is {df['actors_list'].value_counts().idxmax()}"
# Out:
# 'The actor is mentioned the most often is Robert De Niro'
